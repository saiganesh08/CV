# %%
import cv2
import matplotlib.pyplot as plt

# %%
img = cv2.imread("sky.jpg", -1)

print("Image properties : ")
print(f"no of pixels : {img.size}")
print(f"shape : {img.shape}")

img = cv2.resize(img, (300, 300))

cv2.imshow("Sky", img)

cv2.imwrite("original pic of sky.jpg", img)

plt.imshow(img)
cv2.waitKey(0)
cv2.destroyAllWindows()
# Out:
# Image properties :
# no of pixels : 13029120
# shape : (1508, 2880, 3)

# %%
import cv2
img = cv2.imread("sky.jpg")
cv2.imshow("Image", img)
print("Image Properties:")
print("Number of pixels:"+str(img.size))
print("Image dimensions:"+str(img.shape))
cv2.waitKey(0)
cv2.destroyAllWindows()
# Out:
# Image Properties:
# Number of pixels:13029120
# Image dimensions:(1508, 2880, 3)
