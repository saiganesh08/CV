# %%
import cv2 as cv
import numpy as np
from matplotlib import pyplot as plt


img=cv.imread("sky.jpg")
img_array=np.asarray(img)
 
sum=np.sum(img_array)
avg=np.mean(img_array)
std=np.std(img_array)
min=np.min(img_array)
max=np.min(img_array)

plt.imshow(img)
print(f" SUM: {sum}")
print(f" Average: {avg}")
print(f" Standard Deviation: {std}")
print(f" Minimum: {min}")
print(f" Maximum: {max}")
# Out:
#  SUM: 1754897065
#  Average: 134.69037548199725
#  Standard Deviation: 65.2945676617831
#  Minimum: 0
#  Maximum: 0
